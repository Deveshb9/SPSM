# %%
# Devesh Bhogre
# PB45
# SPSM Assignment-2
# Twitter API

# %%
try:
    import json
except ImportError:
    import simplejson as json

# Import the tweepy library
import tweepy

# %%
class MyStreamListener(tweepy.StreamListener):
    def __init__(self, api):
        self.api = api
        self.me = api.me()
    def on_status(self, tweet):
        print(f"{tweet.user.name}:{tweet.text}")
    def on_error(self, status):
        print("Error detected")

# %%
ACCESS_TOKEN = '1095410054809833472-sxTeTxsyMIsG6ujlC9hJXTo83uRZUv'
ACCESS_SECRET = 'zxi0rweBlpFml8MeDxf1bh728dDgXe7FMtzFL1JZtq0Wj'
CONSUMER_KEY = '5mR6t59FKeljYCeIH9OyTQBeg'
CONSUMER_SECRET = 'ahlmHj1f9LjwxiF6qHvUvgRcWwdp9bj2XNrepqneBGJkNUe6up'

# %%
# Setup tweepy to authenticate with Twitter credentials:
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

# %%
# Create the api to connect to twitter with your credentials
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)

# %%
print("Tweets in JSON Format:\n")
for status in tweepy.Cursor(api.home_timeline).items(200):
    print(status._json)
# Out:
# Tweets in JSON Format:
#
# ...

# %%
print("Tweets in Simple Format:\n")
timeline = api.home_timeline()
for tweet in timeline:
    print(f"{tweet.user.name} said {tweet.text}")
# Out:
# Tweets in Simple Format:
#
# Vignesh said RT @AbhishBanerj: Two years ago, a Kerala CPIM leader kicked a pregnant woman on her belly.
#
# She lost her baby.
#
# That woman Jyotsna Jose i…
# Xbox said Playing online with your friends counts as hanging out
# dbrand said you're about 3 years late on this one https://t.co/MqobuqhiUk https://t.co/qxUtYzG5Q3
# Joe Biden said Our country is in the middle of a dramatic spike in COVID-19 cases. Please wear a mask, keep social distancing, and… https://t.co/UGmOj2otDK
# Gaurav Chaudhary said Tech Talks #1305 - PUBG INDIA SCAM, Fastest Phone, iPhone 11 Free, Nokia 3 4, Pixel XE, YouTube Warn… https://t.co/kVaOhesfRh
# Vignesh said RT @MehHarshil: If Canada wants to continue encouraging Khalistan, India should start supporting Quebec sovereignty movement. 👍
# Akhil Narang said Okay it's mostly fine now https://t.co/Ur4LS58mew
# ...

# %%
print("Tweet Searches:\n")
for tweet in api.search(q="MITWPU", lang="en", rpp=10):
    print(f"{tweet.user.name}:{tweet.text}")
# Out:
# Tweet Searches:
#
# MIT World Peace University, Pune:Opt for BTech in Petroleum Engineering at MIT-WPU, Pune and study the skills required to support a large number of… https://t.co/aZzhyzyukG
# MIT-WPU Institutional Relations:Happy Birthday to Shri. @ravishndtv
#  ji-recipient of Ramon Magsaysay Awardee (2019)  A rare personality epitomizing… https://t.co/ahzmdf9r4X
# MIT World Peace University, Pune:Apply with MIT-WPU 3 year LLB program using your MHT-CET scores. Admissions are open. Apply now
# on… https://t.co/MBD5pgOzWy
# MIT World Peace University, Pune:MIT-WPU congratulates all students on their MHT-CET scores. We are now accepting your CET scores for 3 year BEd pro… https://t.co/AuCvyjCKQH
# MIT_SOG:Shri. Gangadhar Nikhade- Sarpanch, Ideal Village - Ozarkhed, Nasik addressed at 2nd Sarpanch Sansad
# Watch Live Str… https://t.co/O0l6s3KBd2
# ...

# %%
# Get user information from Twitter
user = api.get_user("MikezGarcia")
print("User details:")
print(user.name)
print(user.description)
print(user.location)
# Out:
# User details:
# Miguel Garcia
# Software Engineer at @InOrbitAI and Articles Author at @realpython
#
# MSc in Computer Science, I like working with open source techs and playing guitar.
# Argentina

# %%
print("Last 20 Followers:")
for follower in user.followers():
    print(follower.name)
# Out:
# Last 20 Followers:
# Python Is Rad
# Deen Muaz | The Digital_Guy
# Gagan Gulyani
# M87
# Scrapfly
# Ro Augustus
# Daniel Simons
# dhineshbabu 🐍
# Jürgen Münch
# Gabriel Côté
# Cloudical
# Mohamed Hasib
# Anandteerth Ramesh
# Dennis Chukwunta
# Maxi Contieri
# Moiza Dieng
# Erickson Odiaga
# Joanna Jablonski
# Loooorena "La 🐯 Tigresa” Mesa @ #BLM 🖤
# bolu durodola

# %%
# Fetch Trending topics from Twitter
trends_result = api.trends_place(1)
for trend in trends_result[0]["trends"]:
    print(trend["name"])
# Out:
# #WHUMUN
# Millwall
# #XiuminYouServedWell
# #StartUpEp15
# #GSvHTY
# Pogba
# #어서와_시우민
# West Ham
# Bo Nix
# はやぶさ2
# 보컬로이드 노래
# Vinicius
# Sevilla
# Bowen
# Kerem Aktürkoğlu
# Leclerc
# Telles
# hobi
# Justin Fields
# Albon
# Bono
# hoseok
# NÃO VAMOS DESISTIR DE VOCÊ
# Fornals
# ウラヌス
# Benzema
# jikook
# BIEL MERECE RESPEITO
# minseok
# Emre Akbaba
# Russell
# 보고 보카로
# Diagne
# Fulham
# Musiala
# Black Swan
# Lopetegui
# Bottas
# ビーコン
# Vitolo
# McTominay
# 大気圏突入
# 実況ライブ
# GültekinUysal HaberTürkte
# 투디남자
# FkocaDiyalize SözünVar
# Sterling
# Verstappen
# İbo Show
# Modric

# %%
# Fetch live streams from Twitter
tweets_listener = MyStreamListener(api)
stream = tweepy.Stream(api.auth, tweets_listener)
stream.filter(track=["India", "Biden", "Modi"], languages=["en"])
# Out:
# charles black:More than 70 percent of Republican lawmakers did not acknowledge question “Did Biden win election?” Bunch of pussies.
# Trump2020PNW:RT @gatewaypundit: PAUL SPERRY: Pro-Biden Bug Also Suspected in Georgia's Vote-Counting Software via @gatewaypundit https://t.co/9YovOWmRv2
# ImYerHuckleberry:@robreiner It’s actually very simple, Meat. Joe Biden an Kamala Harris are interlopers. And they pose a national se… https://t.co/RDCgMTULj3
# Linda:RT @SchmittNYC: Maxine Water’s daughter, Ilhan Omar’s husband, Joe Biden’s son - it’s the same game every time
# Humberto Zamora Ruiz:RT @DailyMail: 90% of Republicans in Congress WON'T acknowledge Biden's win https://t.co/WdO3RbJG8F
# Proud Leftist Robert:RT @TheUSASingers: Trump &amp; Erik Prince are destabilizing the entire world in order to make Joe Biden’s job as difficult as possible.
#
# How i…
# ...
